# %% [markdown]
# ## UK HOUSE PRICES ANALYSIS
# This exercise is in different parts, treat each part after each other in different coding cells. Make sure you add some descriptive titles, description of your code, comments any analysis with text since it will be for sharing with others.
# Data source: Office of National Statistics

# %% [markdown]
# PART 1
#
# 1-Import the file named: UK_house_price_2023.csv
# 2-Perform exploratory data analyis:
# -check the size of the dataset, summary stats, data cleaning (any missing values?), data transformation (check datatypes), check for outliers
# 3-Analyse the 12 month percentage of change in the UK hosue prices with an appropriate plot:
# -Do you observe any dramatic changes of UK house prices at a particulat time period, if yes what could be the reasons? (google search  if necessary)
# -Observe UK house prices over 2020 to 2023 on a plot. What changes to you observe? (you might need to create a substet of the data before ploting using the loc attribute for instance)

# %%
import pandas as pd

# %%
#import the file named: UK_house_price_2023.csv
df1= pd.read_csv("UK_house_price_2023 (1).csv")
df1
# Out:
#          date  12 month percentage change
# 0    2006 Jan                          6.2
# 1    2006 Feb                          6.5
# 2    2006 Mar                          6.5
# 3    2006 Apr                          7.3
# 4    2006 May                          7.1
# ..        ...                          ...
# 200  2022 Sep                          9.0
# 201  2022 Oct                         11.4
# 202  2022 Nov                         10.2
# 203  2022 Dec                          9.3
# 204  2023 Jan                          6.3
#
# [205 rows x 2 columns]

# %%
df1 = pd.DataFrame(data)
size_in_bytes = df1.memory_usage(deep=True).sum()

print(f"Size of the Pandas DataFrame: {size_in_bytes} bytes")
# Out:
# Size of the Pandas DataFrame: 16128 bytes

# %%
df1.info
# Out:
# <bound method DataFrame.info of          date  12 month percentage change
# 0    2006 Jan                          6.2
# 1    2006 Feb                          6.5
# 2    2006 Mar                          6.5
# 3    2006 Apr                          7.3
# 4    2006 May                          7.1
# ..        ...                          ...
# 200  2022 Sep                          9.0
# 201  2022 Oct                         11.4
# 202  2022 Nov                         10.2
# 203  2022 Dec                          9.3
# 204  2023 Jan                          6.3
#
# [205 rows x 2 columns]>

# %%
df1.describe()
# Out:
#        12 month percentage change
# count                   205.000000
# mean                      3.768293
# std                       5.682051
# min                     -15.600000
# 25%                       1.100000
# 50%                       4.700000
# 75%                       7.900000
# max                      14.100000

# %%
#First 5 rows of the dataset
df1.head()
# Out:
#        date  12 month percentage change
# 0  2006 Jan                          6.2
# 1  2006 Feb                          6.5
# 2  2006 Mar                          6.5
# 3  2006 Apr                          7.3
# 4  2006 May                          7.1

# %%
df1.tail()
# Out:
#          date  12 month percentage change
# 200  2022 Sep                          9.0
# 201  2022 Oct                         11.4
# 202  2022 Nov                         10.2
# 203  2022 Dec                          9.3
# 204  2023 Jan                          6.3

# %%
df1.isnull().sum()
# Out:
# date                           0
# 12 month percentage change     0
# dtype: int64

# %%
df1.shape
# Out:
# (205, 2)

# %%
df1.columns
# Out:
# Index(['date', '12 month percentage change '], dtype='object')

# %%
# %matplotlib inline

# %%
df1.boxplot()
# Out:
# <Axes: >

# %%
date = 'date'
change = '12 month percentage change '
df1[date] = pd.to_datetime(df1[date])
df1 = df1.sort_values(by = date)
plt.figure(figsize=(10,5))
plt.plot(df1[date], df1[change], marker = 'o', linestyle = '-')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.title('% Change of UK House Prices')
# Out:
# Text(0.5, 1.0, '% Change of UK House Prices')

# %%
df1['date'] = pd.to_datetime(df1['date'], format='%Y %b',errors='coerce')
start_date = '2020-01-01'
end_date = '2023-12-31'
subset = df1.loc[(df1['date'] >= start_date) & (df1['date'] <= end_date)]
plt.figure(figsize=(10, 6))
plt.plot(subset['date'], subset['12 month percentage change '])
plt.title('Subset of UK House Prices (2020-2023)')
plt.xlabel('date')
plt.ylabel('12 moth percentage change ')
plt.grid(True)
plt.show()

# %% [markdown]
# PART 2
# 1-Import the file named: UK_house_prices_per_country.csv
# 2-Perform exploratory data analyis:
# -check the size of the dataset, summary stats, data cleaning (any missing values?), data transformation (check datatypes), check for outliers
# 3-Analyse UK house prices for each country in the same plot. Give a conclusion as text

# %%
df2= pd.read_csv("UK_house_prices_per_country (1).csv")
df2
# Out:
#          date  England  Wales   Scotland   Northern Ireland
# 0    2005 Jan   158572  123815      93982            111920
# 1    2005 Feb   158609  121070      93554            111920
# 2    2005 Mar   159642  123052      96638            111920
# 3    2005 Apr   161336  124088     102739            116004
# 4    2005 May   163064  126541     103815            116004
# ..        ...      ...     ...        ...               ...
# 212  2022 Sep   312513  223400     191683            176138
# 213  2022 Oct   312878  222848     192362            175234
# 214  2022 Nov   314626  221720     192063            175234
# 215  2022 Dec   313894  222041     186011            175234
# 216  2023 Jan   310159  216871     185016            175234
#
# [217 rows x 5 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              217 non-null    object
#  1   England           217 non-null    int64
#  2   Wales             217 non-null    int64
#  3   Scotland          217 non-null    int64
#  4   Northern Ireland  217 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 8.6+ KB

# %%
df2.describe()
# Out:
#            Column1      Column2
# count  1000.000000  1000.000000
# mean    500.500000  1500.500000
# std     288.819436   288.819436
# min       1.000000  1001.000000
# 25%     250.750000  1250.750000
# 50%     500.500000  1500.500000
# 75%     750.250000  1750.250000
# max    1000.000000  2000.000000

# %%
df2.head()
# Out:
#    Column1  Column2
# 0        1     1001
# 1        2     1002
# 2        3     1003
# 3        4     1004
# 4        5     1005

# %%
df2.tail()
# Out:
#      Column1  Column2
# 995      996     1996
# 996      997     1997
# 997      998     1998
# 998      999     1999
# 999     1000     2000

# %%
df2.isnull().sum()
# Out:
# Column1    0
# Column2    0
# dtype: int64

# %%
df2.shape
# Out:
# (1000, 2)

# %%
df2.columns
# Out:
# Index(['Column1', 'Column2'], dtype='object')

# %%
# %matplotlib inline

# %%
df2.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# PART 3
# 1-Import the file named: England_house_price_percentage_change.csv
# 2-Perform exploratory data analyis:
# -check the size of the dataset, summary stats, data cleaning (any missing values?), data transformation (check datatypes), check for outliers
# 3-Analyse house prices for each reagion in England. Give a conclusion as text
